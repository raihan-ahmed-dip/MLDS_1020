# %% [markdown]
# # Folder Handling
# Need to import os to work with directory

# %%
import os

# %%
os.getcwd()
# Out:
# 'd:\\Programming\\Python\\MLDS_1020\\FileFolderHandling'

# %%
os.chdir('d:\\Programming\\Python\\MLDS_1020')

# %%
os.chdir(r'd:\Programming\Python\MLDS_1020\FileFolderHandling')

# %%
os.listdir()
# Out:
# ['file1.txt', 'fileHandling.ipynb', 'folderHandling.ipynb']

# %%
os.listdir('FileFolderHandling')
# Out:
# ['file1.txt', 'fileHandling.ipynb', 'folderHandling.ipynb']

# %% [markdown]
# ## Create Directory

# %%
os.chdir('FileFolderHandling')
os.getcwd()
# Out:
# 'd:\\Programming\\Python\\MLDS_1020\\FileFolderHandling'

# %%
os.mkdir('New')

# %%
os.mkdir(r'New\New11')

# %%
os.mkdir('New\\New12')

# %%
# Create recursive directories
os.makedirs(r'Old\Old11')

# %% [markdown]
# ## Rename Directory

# %%
os.rename('Old', 'Renamed')

# %%
os.rename(r'Renamed\Old11', r'Renamed\Renamed11')

# %%
# This also works like move
os.rename(r'New\New12', r'Renamed\New12')

# %% [markdown]
# ## Removing

# %%
os.remove("file1 copy.txt")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In [40], line 1
# ----> 1 os.remove("file1 copy.txt")
#
# FileNotFoundError: [WinError 2] The system cannot find the file specified: 'file1 copy.txt'

# %%
os.removedirs('New')
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# Cell In [41], line 1
# ----> 1 os.removedirs('New')
#
# File C:\Program Files\Python39\lib\os.py:243, in removedirs(name)
#     232 def removedirs(name):
#     233     """removedirs(name)
#     234
#     235     Super-rmdir; remove a leaf directory and all empty intermediate
#    (...)
#     241
#     242     """
# --> 243     rmdir(name)
#     244     head, tail = path.split(name)
#     245     if not tail:
#
# OSError: [WinError 145] The directory is not empty: 'New'

# %% [markdown]
# ## Walking through directories

# %%
os.listdir()
# Out:
# ['file1.txt', 'fileHandling.ipynb', 'folderHandling.ipynb', 'New', 'Renamed']

# %%
os.chdir('..')

# %%
os.walk('.')
# Out:
# <generator object _walk at 0x0000013B56072DD0>

# %%
for path, dirs, files in os.walk('.'):
    print(path, " || ", dirs, " || ", files)
# Out:
# .  ||  ['.env', '.git', 'FileFolderHandling', 'Functions', 'OOP', 'PythonCore']  ||  ['.gitignore', 'LICENSE', 'README.md', 'requirements.txt']
# .\.env  ||  ['etc', 'Include', 'Lib', 'Scripts', 'share']  ||  ['pyvenv.cfg']
# .\.env\etc  ||  ['jupyter']  ||  []
# .\.env\etc\jupyter  ||  ['jupyter_server_config.d', 'nbconfig']  ||  []
# .\.env\etc\jupyter\jupyter_server_config.d  ||  []  ||  ['nbclassic.json']
# .\.env\etc\jupyter\nbconfig  ||  ['notebook.d']  ||  []
# .\.env\etc\jupyter\nbconfig\notebook.d  ||  []  ||  ['widgetsnbextension.json']
# .\.env\Include  ||  []  ||  []
# .\.env\Lib  ||  ['site-packages']  ||  []
# ...

# %% [markdown]
# ## Working with Paths

# %%
os.path.exists(r'New\New11')
# Out:
# False

# %%
os.getcwd()
# Out:
# 'd:\\Programming\\Python\\MLDS_1020'

# %%
os.path.join('FileFolderHandling', 'New', 'New11')
# Out:
# 'FileFolderHandling\\New\\New11'
